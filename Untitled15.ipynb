# %%
import openai
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import os
import time
import json

# Set up your OpenAI API key securely using environment variables
# Ensure you set this environment variable before running the script


# Load the datasets
test_data = pd.read_csv('PURE_test.csv')
train_data = pd.read_csv('PURE_train.csv')

# %% [markdown]
# ### Prompt Templates

# %%
# Define prompt templates
PROMPT_TEMPLATES = {
    "In-Context Learning Prompts": (
        "Given a statement, determine whether it is a 'requirement' or 'non-requirement'. "
        "A 'requirement' specifies a condition, specification, or feature that must be fulfilled. "
        "A 'non-requirement' is any statement that does not impose a condition or specification to be met.\n\n"
        "Example 1 (Requirement):\n"
        "\"NPAC SMS shall accept the following data from the NPAC personnel or old Service Provider "
        "upon Subscription Version creation for an Inter-Service Provider port: Local Number Portability Type.\"\n"
        "Classification: Requirement\n\n"
        "Example 2 (Not a Requirement):\n"
        "\"The approach to operation and maintenance is based on remote supervision and monitoring of the wind turbine(s) "
        "but the amount of operational data needed and the need for update of data is very moderate.\"\n"
        "Classification: Non-Requirement"
    ),
    "Few-Shot Exemplar-based Prompt": (
        "Below are a few statements. Your task is to classify each as either a 'Requirement' or 'Non-Requirement'. "
        "A 'Requirement' is a statement that specifies a necessary condition or feature that must be met. "
        "A 'Non-Requirement' does not specify any necessary condition.\n\n"
        "Example 1 (Requirement):\n"
        "\"NPAC SMS shall accept the following data from the NPAC personnel or old Service Provider upon Subscription Version creation for an Inter-Service Provider port.\"\n"
        "Classification: Requirement\n\n"
        "Example 2 (Requirement):\n"
        "\"Visual Input: The conferencing feature requires a high resolution video input device.\"\n"
        "Classification: Requirement\n\n"
        "Example 3 (Non-Requirement):\n"
        "\"The approach to operation and maintenance is based on remote supervision and monitoring of the wind turbine(s).\"\n"
        "Classification: Non-Requirement\n\n"
        "Example 4 (Non-Requirement):\n"
        "\"ESOC Data Disposition system Interface control Document (DDID) to be released sometime 2000.\"\n"
        "Classification: Non-Requirement"
    ),
    "Ultimate Prompt": (
        "### Task: Classify the following text as \"requirement\" or \"non-requirement.\"\n\n"
        "### Definitions:\n"
        "- *Requirement:* A statement that specifies a mandatory functionality, feature, constraint, or operational need. "
        "It typically uses actionable terms like \"shall,\" \"must,\" \"requires,\" or clearly indicates a technical or functional demand.\n"
        "- *Non-Requirement:* A statement that is descriptive, procedural, informational, or otherwise lacks specificity about a mandatory functionality or constraint. "
        "These may reference requirements without being actionable themselves.\n\n"
        "### Persona:\n"
        "You are a highly experienced software engineer with over 25 years of expertise in requirements engineering. "
        "Your role is to carefully distinguish between actionable requirements and supplementary or descriptive information. "
        "You are methodical, objective, and precise in your analysis.\n\n"
        "### Instructions:\n"
        "1. Read the text carefully.\n"
        "2. Compare it to the definitions provided above.\n"
        "3. Follow this decision-making process:\n"
        "   - *Step 1:* Does the text describe a mandatory functionality, feature, or constraint?\n"
        "   - *Step 2:* Does it include actionable terms such as \"shall,\" \"must,\" \"requires,\" or similar?\n"
        "   - *Step 3:* If descriptive, procedural, or lacking specificity, classify as \"non-requirement.\"\n"
        "4. Be neutral and avoid assuming the text belongs to a specific class. Use examples to guide your decision.\n"
        "5. Output your classification in the following JSON format:\n\n"
        "json\n"
        "{\n"
        "  \"reasoning\": \"{Explain step-by-step reasoning here. Highlight whether the text aligns with actionable requirements or descriptive content.}\",\n"
        "  \"label\": \"{Requirement/Non-Requirement}\"\n"
        "}\n\n"
        "### Examples:\n"
        "- *Requirement:* \"NPAC SMS shall accept the following data from the NPAC personnel: Port Type, Ported Telephone Number(s), Due Date, Old Service Provider ID, and Status Change Cause Code.\"\n"
        "- *Requirement:* \"System administrators can create shared folders to allow or disallow staff to run specific reports.\"\n"
        "- *Non-Requirement:* \"The approach to operation and maintenance is based on remote supervision and monitoring of the wind turbine(s).\"\n"
        "- *Non-Requirement:* \"The remaining sections of the document contain the requirements for the system.\"\n\n"
        "### Analyze and Classify:\n"
        "Text: \"{Insert text here}\""
    )
}

# %% [markdown]
# ### Utility Functions

# %%
def get_sentences(data: pd.DataFrame, column_name: str = "Requirement") -> list:
    """
    Extracts sentences from the specified column in the DataFrame.

    Args:
        data (pd.DataFrame): The DataFrame containing the data.
        column_name (str): The column name to extract sentences from.

    Returns:
        list: A list of sentences.
    """
    if column_name not in data.columns:
        raise ValueError(f"Column '{column_name}' not found in the dataset.")

    sentence_list = data[column_name].dropna().astype(str).tolist()
    return sentence_list

def get_true_label(data: pd.DataFrame, column_name: str = "Req/Not Req") -> list:
    """
    Extracts true labels from the specified column in the DataFrame.

    Args:
        data (pd.DataFrame): The DataFrame containing the data.
        column_name (str): The column name to extract labels from.

    Returns:
        list: A list of boolean labels.
    """
    if column_name not in data.columns:
        raise ValueError(f"Column '{column_name}' not found in the dataset.")

    label_list = data[column_name].apply(lambda x: True if str(x).strip().lower() == "req" else False).tolist()
    return label_list

def classify_sentence(sentence: str, prompt_type: str = "zero-shot") -> bool:
    """
    Classifies a single sentence using the specified prompting technique.

    Args:
        sentence (str): The sentence to classify.
        prompt_type (str): The type of prompt to use ('zero-shot' or 'cot').

    Returns:
        bool: The classification result (True for requirement, False otherwise).
    """
    prompt = PROMPT_TEMPLATES.get(prompt_type)
    if not prompt:
        raise ValueError(f"Unsupported prompt_type '{prompt_type}'. Choose from {list(PROMPT_TEMPLATES.keys())}.")

    # Structure the prompt for a single sentence
    user_message = prompt.replace("{Insert text here}", sentence)
    
    # print("Our message is", user_message)
    

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",  # Change to 'gpt-4' if you have access and prefer to use it
            messages=[
                        {            
                         "role": "system",
                         "content": (
                            "You are a highly experienced software engineer with over 25 years of expertise in requirements engineering. "
                            "Your role is to carefully distinguish between actionable requirements and supplementary or descriptive information. "
                            "You are methodical, objective, and precise in your analysis.")
                        },
                        {
                            "role": "user",
                            "content": (user_message)
                        }
                        
            ],
            temperature=0,  # Deterministic output
            max_tokens=500  # Minimal tokens since response is simple
        )
        

        # Extract and parse the response
        response_content = response['choices'][0]['message']['content'].strip()
        
        print("the response content is:", response_content)
        
        result_data = json.loads(response_content)
        
        # Extract and return the label
        label = result_data['label']
        
        if label == "Requirement":
            return True
        elif label == "Non-Requirement":
            return False
        else:
            return "The label is not either Requirement/Non-Requirement"
        

    except openai.error.RateLimitError as e:
        print(f"Rate limit exceeded: {e}. Waiting for 60 seconds.")
        time.sleep(60)  # Wait before retrying
        return classify_sentence(sentence, prompt_type)  # Retry after delay

    except openai.error.InvalidRequestError as e:
        print(f"Invalid request for sentence: \"{sentence}\". Error: {e}")
        return False  # Defaulting to False in case of error

    except Exception as e:
        print(f"Unexpected error for sentence: \"{sentence}\". Error: {e}")
        return False  # Defaulting to False in case of error

def evaluation(y_true: list, y_pred: list) -> dict:
    """
    Evaluates the classification performance by calculating accuracy, precision, recall, and F1 score.

    Args:
        y_true (list): The true labels.
        y_pred (list): The predicted labels.

    Returns:
        dict: A dictionary containing accuracy, precision, recall, and F1 score.
    """
    if not y_true or not y_pred:
        return {"error": "One of the label lists is empty."}
    if len(y_true) != len(y_pred):
        return {"error": "The length of true labels and predicted labels must be the same."}

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    metrics = {
        "accuracy": round(accuracy, 4),
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1_score": round(f1, 4)
    }

    print(f"\nEvaluation Metrics:")
    print(f"Accuracy: {metrics['accuracy']}")
    print(f"Precision: {metrics['precision']}")
    print(f"Recall: {metrics['recall']}")
    print(f"F1 Score: {metrics['f1_score']}")

    return metrics

# %% [markdown]
# ### In-Context Learning Prompts

# %%
try:
    # Select the prompting technique: 'zero-shot' or 'cot'
    prompt_type = "In-Context Learning Prompts"  # Change to 'cot' for Chain-of-Thought prompting

    print(f"Starting classification using {prompt_type} prompting.\n")

    # Extract 50 sentences from the test dataset
    sentences = get_sentences(test_data, column_name="Requirement")[:50]

    print(f"Processing the following 50 sentences:\n")
    for idx, sentence in enumerate(sentences, 1):
        print(f"{idx}. {sentence}")
    print("\nClassifying...\n")

    # Classify each sentence individually
    predictions = []
    for idx, sentence in enumerate(sentences, 1):
        prediction = classify_sentence(sentence, prompt_type=prompt_type)
        predictions.append(prediction)
        print(f"Sentence {idx}: \"{sentence}\" => {'Requirement' if prediction else 'Not Requirement'}")
        time.sleep(1)  # To respect rate limits; adjust as necessary

    # Assuming you have the ground truth labels for the test set
    # For demonstration, I'll extract them similarly
    ground_truth_labels = get_true_label(test_data, column_name="Req/Not Req")[:50]

    # Evaluate the results
    metrics = evaluation(ground_truth_labels, predictions)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Starting classification using In-Context Learning Prompts prompting.
#
# Processing the following 50 sentences:
#
# 1. System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges.
# 2. Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions.
# 3. As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software.
# 4. System Initialization shall [SRS014] initiate the watchdog timer.
# 5. System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor..
# 6. System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds.
# 7. System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active.
# 8. If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP.
# 9. If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP.
# 10. System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS.
# 11. The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group.
# 12. The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP.
# 13. The application can use this time on the ICP to initialize I/O boards.
# 14. System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance.
# 15. The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP.
# 16. The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal.
# 17. Note that FTSS will not fail the FCR if this signal is not received within this time.
# 18. FTSS will wait until the normal ICP presence test fails.
# 19. The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE.
# 20. System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt.
# 21. This will allow the interrupt handler to initiate normal activities.
# 22. System Initialization, from hardware reset to starting of the 50 Hz timer, shall [SRS015] take no longer than 1.5 minutes.
# 23. Whenever the 50 Hz timer interrupt occurs, the interrupt handler invokes the scheduler (there are various ways to implement this invocation, such as using a procedure call or by setting an event; no specific implementation is to be inferred).
# 24. The scheduler allows the application to create lists of tasks that run during a given segment of time, at various rates.
# 25. The application can create "vehicle modes" to designate a unique segment.
# 26. Significantly modified the structure of the SRS .
# 27. Requirements from version 1.0 were reformatted to utilize the new structure.
# 28. Expanded the requirements for device status.
# 29. Added requirements for device command/control.
# 30. Added requirements for remote control user interface.
# 31. Revised to reflect changes from SICD and CICD version 2.3.
# 32. Incorporated input from DFW Regional Software Task Force into document.
# 33. Major new additions included: Ramp Meters Highway Advisory Radio (HAR), Traffic Signals Environmental Sensor Stations (ESS), High Occupancy Vehicle (HOV) Lanes, Parking Lots, School Zones, Railroad Crossings, Reversible Lanes, Dynamic Lanes, Transit.
# 34. This Software Requirements Specification (SRS) provides the requirements for the Center-to- Center Communications (C2C) Communications project.
# 35. This document describes the requirements for the Dallas/Ft.
# 36. Worth (DFW) Regional “Center-to- Center (C2C) Communications Network” that is based on a Texas Department of Transportation (TxDOT) C2C project.
# 37. The TxDOT C2c project initially connected the DFW TxDOT Traffic Management Centers (TMCs).
# 38. This C2C infrastructure implements a repository for traffic data and provides a mechanism to exchange device control information between TMCs.
# 39. The C2C project will be implemented using the evolving ITS Traffic Management Data Dictionary (TMDD) standard, the message sets associated with TMDD, other ITS Data Elements and Message Sets.
# 40. The use of ITS standards will create a system that is reusable for other ITS application areas and will provide the State of Texas with a baseline system that can be cost effectively extended in the future.
# 41. The C2C infrastructure must interconnect several dissimilar traffic management systems.
# 42. In order to create the C2C infrastructure, interfaces to the existing systems will be created.
# 43. The data from these interfaces will communicate with the existing system in a “system specific” format.
# 44. The data being deposited into the C2C infrastructure will be converted to a standard format (based on the ITS standards).
# 45. The C2C infrastructure is being created using a series of building blocks.
# 46. These building blocks allow the software to be utilized in a number of configurations (by simply altering the configuration parameters of the software).
# 47. In a region such as Dallas/Ft. Worth, multiple instances of the building blocks will be utilized.
# 48. The software is being designed so that multiple instances of a building block can be deployed by simply “configuring” the building block of operation within a specific agency.
# 49. Conceptually, the C2C infrastructure would be deployed as depicted in the following diagram:
# 50. Any data that is passed into the “cloud” in the above figure will be based on the ITS standards.
#
# Classifying...
#
# Sentence 1: "System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges." => Not Requirement
# Sentence 2: "Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions." => Requirement
# Sentence 3: "As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software." => Requirement
# Sentence 4: "System Initialization shall [SRS014] initiate the watchdog timer." => Requirement
# Sentence 5: "System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor.." => Requirement
# Sentence 6: "System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds." => Requirement
# Sentence 7: "System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active." => Requirement
# Sentence 8: "If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP." => Requirement
# Sentence 9: "If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP." => Requirement
# Sentence 10: "System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS." => Requirement
# Sentence 11: "The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group." => Requirement
# Sentence 12: "The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP. " => Requirement
# Sentence 13: "The application can use this time on the ICP to initialize I/O boards." => Not Requirement
# Sentence 14: "System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance." => Requirement
# Sentence 15: "The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP." => Requirement
# Sentence 16: "The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal. " => Requirement
# Sentence 17: "Note that FTSS will not fail the FCR if this signal is not received within this time." => Requirement
# Sentence 18: "FTSS will wait until the normal ICP presence test fails." => Requirement
# Sentence 19: "The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE." => Requirement
# Sentence 20: "System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt. " => Requirement
# Sentence 21: "This will allow the interrupt handler to initiate normal activities." => Not Requirement
# Sentence 22: "System Initialization, from hardware reset to starting of the 50 Hz timer, shall [SRS015] take no longer than 1.5 minutes." => Requirement
# Sentence 23: "Whenever the 50 Hz timer interrupt occurs, the interrupt handler invokes the scheduler (there are various ways to implement this invocation, such as using a procedure call or by setting an event; no specific implementation is to be inferred). " => Requirement
# Sentence 24: "The scheduler allows the application to create lists of tasks that run during a given segment of time, at various rates." => Not Requirement
# Sentence 25: "The application can create "vehicle modes" to designate a unique segment." => Not Requirement
# Sentence 26: "Significantly modified the structure of the SRS ." => Not Requirement
# Sentence 27: "Requirements from version 1.0 were reformatted to utilize the new structure." => Not Requirement
# Sentence 28: "Expanded the requirements for device status." => Not Requirement
# Sentence 29: "Added requirements for device command/control." => Requirement
# Sentence 30: "Added requirements for remote control user interface." => Requirement
# Sentence 31: "Revised to reflect changes from SICD and CICD version 2.3." => Not Requirement
# Sentence 32: "Incorporated input from DFW Regional Software Task Force into document. " => Not Requirement
# Sentence 33: "Major new additions included: Ramp Meters Highway Advisory Radio (HAR), Traffic Signals Environmental Sensor Stations (ESS), High Occupancy Vehicle (HOV) Lanes, Parking Lots, School Zones, Railroad Crossings, Reversible Lanes, Dynamic Lanes, Transit." => Not Requirement
# Sentence 34: "This Software Requirements Specification (SRS) provides the requirements for the Center-to- Center Communications (C2C) Communications project." => Requirement
# Sentence 35: "This document describes the requirements for the Dallas/Ft. " => Not Requirement
# Sentence 36: "Worth (DFW) Regional “Center-to- Center (C2C) Communications Network” that is based on a Texas Department of Transportation (TxDOT) C2C project. " => Not Requirement
# Sentence 37: "The TxDOT C2c project initially connected the DFW TxDOT Traffic Management Centers (TMCs). " => Not Requirement
# Sentence 38: "This C2C infrastructure implements a repository for traffic data and provides a mechanism to exchange device control information between TMCs." => Requirement
# Sentence 39: "The C2C project will be implemented using the evolving ITS Traffic Management Data Dictionary (TMDD) standard, the message sets associated with TMDD, other ITS Data Elements and Message Sets. " => Not Requirement
# Sentence 40: "The use of ITS standards will create a system that is reusable for other ITS application areas and will provide the State of Texas with a baseline system that can be cost effectively extended in the future." => Not Requirement
# Sentence 41: "The C2C infrastructure must interconnect several dissimilar traffic management systems." => Requirement
# Sentence 42: "In order to create the C2C infrastructure, interfaces to the existing systems will be created. " => Requirement
# Sentence 43: "The data from these interfaces will communicate with the existing system in a “system specific” format. " => Not Requirement
# Sentence 44: "The data being deposited into the C2C infrastructure will be converted to a standard format (based on the ITS standards)." => Requirement
# Sentence 45: "The C2C infrastructure is being created using a series of building blocks." => Not Requirement
# Sentence 46: "These building blocks allow the software to be utilized in a number of configurations (by simply altering the configuration parameters of the software)." => Not Requirement
# Sentence 47: "In a region such as Dallas/Ft. Worth, multiple instances of the building blocks will be utilized. " => Not Requirement
# Sentence 48: "The software is being designed so that multiple instances of a building block can be deployed by simply “configuring” the building block of operation within a specific agency. " => Not Requirement
# Sentence 49: "Conceptually, the C2C infrastructure would be deployed as depicted in the following diagram:" => Not Requirement
# Sentence 50: "Any data that is passed into the “cloud” in the above figure will be based on the ITS standards. " => Requirement
#
# Evaluation Metrics:
# Accuracy: 0.74
# Precision: 0.7143
# Recall: 0.8
# F1 Score: 0.7547

# %%
metrics = evaluation(ground_truth_labels, predictions)

# %% [markdown]
# ### "Few-Shot Exemplar-based Prompt"

# %%
# Repeat the process for CoT prompting if desired
try:
    prompt_type = "Few-Shot Exemplar-based Prompt"  # Change to 'zero-shot' for Zero-shot prompting

    print(f"\nStarting classification using {prompt_type} prompting.\n")

    # Extract the same 50 sentences for consistency
    sentences = get_sentences(test_data, column_name="Requirement")[:50]
    print(f"Processing the following 50 sentences:\n")
    for idx, sentence in enumerate(sentences, 1):
        print(f"{idx}. {sentence}")
    print("\nClassifying...\n")

    # Classify each sentence individually
    predictions = []
    for idx, sentence in enumerate(sentences, 1):
        prediction = classify_sentence(sentence, prompt_type=prompt_type)
        predictions.append(prediction)
        print(f"Sentence {idx}: \"{sentence}\" => {'Requirement' if prediction else 'Not Requirement'}")
        time.sleep(1)  # To respect rate limits; adjust as necessary

    # Extract ground truth labels
    ground_truth_labels = get_true_label(test_data, column_name="Req/Not Req")[:50]

    # Evaluate the results
    metrics = evaluation(ground_truth_labels, predictions)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Starting classification using Few-Shot Exemplar-based Prompt prompting.
#
# Processing the following 50 sentences:
#
# 1. System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges.
# 2. Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions.
# 3. As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software.
# 4. System Initialization shall [SRS014] initiate the watchdog timer.
# 5. System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor..
# 6. System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds.
# 7. System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active.
# 8. If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP.
# 9. If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP.
# 10. System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS.
# 11. The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group.
# 12. The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP.
# 13. The application can use this time on the ICP to initialize I/O boards.
# 14. System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance.
# 15. The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP.
# 16. The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal.
# 17. Note that FTSS will not fail the FCR if this signal is not received within this time.
# 18. FTSS will wait until the normal ICP presence test fails.
# 19. The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE.
# 20. System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt.
# 21. This will allow the interrupt handler to initiate normal activities.
# 22. System Initialization, from hardware reset to starting of the 50 Hz timer, shall [SRS015] take no longer than 1.5 minutes.
# 23. Whenever the 50 Hz timer interrupt occurs, the interrupt handler invokes the scheduler (there are various ways to implement this invocation, such as using a procedure call or by setting an event; no specific implementation is to be inferred).
# 24. The scheduler allows the application to create lists of tasks that run during a given segment of time, at various rates.
# 25. The application can create "vehicle modes" to designate a unique segment.
# 26. Significantly modified the structure of the SRS .
# 27. Requirements from version 1.0 were reformatted to utilize the new structure.
# 28. Expanded the requirements for device status.
# 29. Added requirements for device command/control.
# 30. Added requirements for remote control user interface.
# 31. Revised to reflect changes from SICD and CICD version 2.3.
# 32. Incorporated input from DFW Regional Software Task Force into document.
# 33. Major new additions included: Ramp Meters Highway Advisory Radio (HAR), Traffic Signals Environmental Sensor Stations (ESS), High Occupancy Vehicle (HOV) Lanes, Parking Lots, School Zones, Railroad Crossings, Reversible Lanes, Dynamic Lanes, Transit.
# 34. This Software Requirements Specification (SRS) provides the requirements for the Center-to- Center Communications (C2C) Communications project.
# 35. This document describes the requirements for the Dallas/Ft.
# 36. Worth (DFW) Regional “Center-to- Center (C2C) Communications Network” that is based on a Texas Department of Transportation (TxDOT) C2C project.
# 37. The TxDOT C2c project initially connected the DFW TxDOT Traffic Management Centers (TMCs).
# 38. This C2C infrastructure implements a repository for traffic data and provides a mechanism to exchange device control information between TMCs.
# 39. The C2C project will be implemented using the evolving ITS Traffic Management Data Dictionary (TMDD) standard, the message sets associated with TMDD, other ITS Data Elements and Message Sets.
# 40. The use of ITS standards will create a system that is reusable for other ITS application areas and will provide the State of Texas with a baseline system that can be cost effectively extended in the future.
# 41. The C2C infrastructure must interconnect several dissimilar traffic management systems.
# 42. In order to create the C2C infrastructure, interfaces to the existing systems will be created.
# 43. The data from these interfaces will communicate with the existing system in a “system specific” format.
# 44. The data being deposited into the C2C infrastructure will be converted to a standard format (based on the ITS standards).
# 45. The C2C infrastructure is being created using a series of building blocks.
# 46. These building blocks allow the software to be utilized in a number of configurations (by simply altering the configuration parameters of the software).
# 47. In a region such as Dallas/Ft. Worth, multiple instances of the building blocks will be utilized.
# 48. The software is being designed so that multiple instances of a building block can be deployed by simply “configuring” the building block of operation within a specific agency.
# 49. Conceptually, the C2C infrastructure would be deployed as depicted in the following diagram:
# 50. Any data that is passed into the “cloud” in the above figure will be based on the ITS standards.
#
# Classifying...
#
# Unexpected response for sentence: "System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges." => 'Classification: Non-Requirement'
# Sentence 1: "System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges." => Not Requirement
# Unexpected response for sentence: "Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions." => 'Classification: Requirement'
# Sentence 2: "Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions." => Not Requirement
# Unexpected response for sentence: "As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software." => 'Classification: Requirement'
# Sentence 3: "As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS014] initiate the watchdog timer." => 'Classification: Requirement'
# Sentence 4: "System Initialization shall [SRS014] initiate the watchdog timer." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor.." => 'Classification: Requirement'
# Sentence 5: "System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor.." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds." => 'Classification: Requirement'
# Sentence 6: "System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active." => 'Classification: Requirement'
# Sentence 7: "System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active." => Not Requirement
# Unexpected response for sentence: "If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP." => 'Classification: Requirement'
# Sentence 8: "If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP." => Not Requirement
# Unexpected response for sentence: "If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP." => 'Classification: Requirement'
# Sentence 9: "If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS." => 'Classification: Requirement'
# Sentence 10: "System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS." => Not Requirement
# Unexpected response for sentence: "The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group." => 'Classification: Requirement'
# Sentence 11: "The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group." => Not Requirement
# Unexpected response for sentence: "The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP. " => 'Classification: Requirement'
# Sentence 12: "The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP. " => Not Requirement
# Unexpected response for sentence: "The application can use this time on the ICP to initialize I/O boards." => 'Classification: Non-Requirement'
# Sentence 13: "The application can use this time on the ICP to initialize I/O boards." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance." => 'Classification: Requirement'
# Sentence 14: "System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance." => Not Requirement
# Unexpected response for sentence: "The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP." => 'Classification: Requirement'
# Sentence 15: "The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP." => Not Requirement
# Unexpected response for sentence: "The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal. " => 'Classification: Requirement'
# Sentence 16: "The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal. " => Not Requirement
# Unexpected response for sentence: "Note that FTSS will not fail the FCR if this signal is not received within this time." => 'Classification: Requirement'
# Sentence 17: "Note that FTSS will not fail the FCR if this signal is not received within this time." => Not Requirement
# Unexpected response for sentence: "FTSS will wait until the normal ICP presence test fails." => 'Classification: Requirement'
# Sentence 18: "FTSS will wait until the normal ICP presence test fails." => Not Requirement
# Unexpected response for sentence: "The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE." => 'Classification: Requirement'
# Sentence 19: "The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE." => Not Requirement
# Unexpected response for sentence: "System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt. " => 'Classification: Requirement'
# Sentence 20: "System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt. " => Not Requirement
# Unexpected response for sentence: "This will allow the interrupt handler to initiate normal activities." => 'Classification: Non-Requirement'
# Sentence 21: "This will allow the interrupt handler to initiate normal activities." => Not Requirement
# Unexpected response for sentence: "System Initialization, from hardware reset to starting of the 50 Hz timer, shall [SRS015] take no longer than 1.5 minutes." => 'Classification: Requirement'
# Sentence 22: "System Initialization, from hardware reset to starting of the 50 Hz timer, shall [SRS015] take no longer than 1.5 minutes." => Not Requirement
# Unexpected response for sentence: "Whenever the 50 Hz timer interrupt occurs, the interrupt handler invokes the scheduler (there are various ways to implement this invocation, such as using a procedure call or by setting an event; no specific implementation is to be inferred). " => 'Classification: Non-Requirement'
# Sentence 23: "Whenever the 50 Hz timer interrupt occurs, the interrupt handler invokes the scheduler (there are various ways to implement this invocation, such as using a procedure call or by setting an event; no specific implementation is to be inferred). " => Not Requirement
# Unexpected response for sentence: "The scheduler allows the application to create lists of tasks that run during a given segment of time, at various rates." => 'Classification: Requirement'
# Sentence 24: "The scheduler allows the application to create lists of tasks that run during a given segment of time, at various rates." => Not Requirement
# Unexpected response for sentence: "The application can create "vehicle modes" to designate a unique segment." => 'Classification: Non-Requirement'
# Sentence 25: "The application can create "vehicle modes" to designate a unique segment." => Not Requirement
# Unexpected response for sentence: "Significantly modified the structure of the SRS ." => 'Classification: Non-Requirement'
# Sentence 26: "Significantly modified the structure of the SRS ." => Not Requirement
# Unexpected response for sentence: "Requirements from version 1.0 were reformatted to utilize the new structure." => 'Classification: Non-Requirement'
# Sentence 27: "Requirements from version 1.0 were reformatted to utilize the new structure." => Not Requirement
# Unexpected response for sentence: "Expanded the requirements for device status." => 'Classification: Non-Requirement'
# Sentence 28: "Expanded the requirements for device status." => Not Requirement
# Unexpected response for sentence: "Added requirements for device command/control." => 'Classification: Non-Requirement'
# Sentence 29: "Added requirements for device command/control." => Not Requirement
# Unexpected response for sentence: "Added requirements for remote control user interface." => 'Classification: Requirement'
# Sentence 30: "Added requirements for remote control user interface." => Not Requirement
# Unexpected response for sentence: "Revised to reflect changes from SICD and CICD version 2.3." => 'Classification: Non-Requirement'
# Sentence 31: "Revised to reflect changes from SICD and CICD version 2.3." => Not Requirement
# Unexpected response for sentence: "Incorporated input from DFW Regional Software Task Force into document. " => 'Classification: Non-Requirement'
# Sentence 32: "Incorporated input from DFW Regional Software Task Force into document. " => Not Requirement
# Unexpected response for sentence: "Major new additions included: Ramp Meters Highway Advisory Radio (HAR), Traffic Signals Environmental Sensor Stations (ESS), High Occupancy Vehicle (HOV) Lanes, Parking Lots, School Zones, Railroad Crossings, Reversible Lanes, Dynamic Lanes, Transit." => 'Classification: Non-Requirement'
# Sentence 33: "Major new additions included: Ramp Meters Highway Advisory Radio (HAR), Traffic Signals Environmental Sensor Stations (ESS), High Occupancy Vehicle (HOV) Lanes, Parking Lots, School Zones, Railroad Crossings, Reversible Lanes, Dynamic Lanes, Transit." => Not Requirement
# Unexpected response for sentence: "This Software Requirements Specification (SRS) provides the requirements for the Center-to- Center Communications (C2C) Communications project." => 'Classification: Non-Requirement'
# Sentence 34: "This Software Requirements Specification (SRS) provides the requirements for the Center-to- Center Communications (C2C) Communications project." => Not Requirement
# Unexpected response for sentence: "This document describes the requirements for the Dallas/Ft. " => 'Classification: Non-Requirement'
# Sentence 35: "This document describes the requirements for the Dallas/Ft. " => Not Requirement
# Unexpected response for sentence: "Worth (DFW) Regional “Center-to- Center (C2C) Communications Network” that is based on a Texas Department of Transportation (TxDOT) C2C project. " => 'Classification: Non-Requirement'
# Sentence 36: "Worth (DFW) Regional “Center-to- Center (C2C) Communications Network” that is based on a Texas Department of Transportation (TxDOT) C2C project. " => Not Requirement
# Unexpected response for sentence: "The TxDOT C2c project initially connected the DFW TxDOT Traffic Management Centers (TMCs). " => 'Classification: Non-Requirement'
# Sentence 37: "The TxDOT C2c project initially connected the DFW TxDOT Traffic Management Centers (TMCs). " => Not Requirement
# Unexpected response for sentence: "This C2C infrastructure implements a repository for traffic data and provides a mechanism to exchange device control information between TMCs." => 'Classification: Requirement'
# Sentence 38: "This C2C infrastructure implements a repository for traffic data and provides a mechanism to exchange device control information between TMCs." => Not Requirement
# Unexpected response for sentence: "The C2C project will be implemented using the evolving ITS Traffic Management Data Dictionary (TMDD) standard, the message sets associated with TMDD, other ITS Data Elements and Message Sets. " => 'Classification: Non-Requirement'
# Sentence 39: "The C2C project will be implemented using the evolving ITS Traffic Management Data Dictionary (TMDD) standard, the message sets associated with TMDD, other ITS Data Elements and Message Sets. " => Not Requirement
# Unexpected response for sentence: "The use of ITS standards will create a system that is reusable for other ITS application areas and will provide the State of Texas with a baseline system that can be cost effectively extended in the future." => 'Classification: Non-Requirement'
# Sentence 40: "The use of ITS standards will create a system that is reusable for other ITS application areas and will provide the State of Texas with a baseline system that can be cost effectively extended in the future." => Not Requirement
# Unexpected response for sentence: "The C2C infrastructure must interconnect several dissimilar traffic management systems." => 'Classification: Requirement'
# Sentence 41: "The C2C infrastructure must interconnect several dissimilar traffic management systems." => Not Requirement
# Unexpected response for sentence: "In order to create the C2C infrastructure, interfaces to the existing systems will be created. " => 'Classification: Requirement'
# Sentence 42: "In order to create the C2C infrastructure, interfaces to the existing systems will be created. " => Not Requirement
# Unexpected response for sentence: "The data from these interfaces will communicate with the existing system in a “system specific” format. " => 'Classification: Non-Requirement'
# Sentence 43: "The data from these interfaces will communicate with the existing system in a “system specific” format. " => Not Requirement
# Unexpected response for sentence: "The data being deposited into the C2C infrastructure will be converted to a standard format (based on the ITS standards)." => 'Classification: Requirement'
# Sentence 44: "The data being deposited into the C2C infrastructure will be converted to a standard format (based on the ITS standards)." => Not Requirement
# Unexpected response for sentence: "The C2C infrastructure is being created using a series of building blocks." => 'Classification: Non-Requirement'
# Sentence 45: "The C2C infrastructure is being created using a series of building blocks." => Not Requirement
# Unexpected response for sentence: "These building blocks allow the software to be utilized in a number of configurations (by simply altering the configuration parameters of the software)." => 'Classification: Non-Requirement'
# Sentence 46: "These building blocks allow the software to be utilized in a number of configurations (by simply altering the configuration parameters of the software)." => Not Requirement
# Unexpected response for sentence: "In a region such as Dallas/Ft. Worth, multiple instances of the building blocks will be utilized. " => 'Classification: Non-Requirement'
# Sentence 47: "In a region such as Dallas/Ft. Worth, multiple instances of the building blocks will be utilized. " => Not Requirement
# Unexpected response for sentence: "The software is being designed so that multiple instances of a building block can be deployed by simply “configuring” the building block of operation within a specific agency. " => 'Classification: Non-Requirement'
# Sentence 48: "The software is being designed so that multiple instances of a building block can be deployed by simply “configuring” the building block of operation within a specific agency. " => Not Requirement
# Unexpected response for sentence: "Conceptually, the C2C infrastructure would be deployed as depicted in the following diagram:" => 'Classification: Non-Requirement'
# Sentence 49: "Conceptually, the C2C infrastructure would be deployed as depicted in the following diagram:" => Not Requirement
# Unexpected response for sentence: "Any data that is passed into the “cloud” in the above figure will be based on the ITS standards. " => 'Classification: Requirement'
# Sentence 50: "Any data that is passed into the “cloud” in the above figure will be based on the ITS standards. " => Not Requirement
#
# Evaluation Metrics:
# Accuracy: 0.5
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0

# %% [markdown]
# ### Ultimate Prompt

# %%
# Repeat the process for CoT prompting if desired
try:
    prompt_type = "Ultimate Prompt"  # Change to 'zero-shot' for Zero-shot prompting

    print(f"\nStarting classification using {prompt_type} prompting.\n")

    # Extract the same 50 sentences for consistency
    sentences = get_sentences(test_data, column_name="Requirement")[:20]
    print(f"Processing the following 50 sentences:\n")
    for idx, sentence in enumerate(sentences, 1):
        print(f"{idx}. {sentence}")
    print("\nClassifying...\n")

    # Classify each sentence individually
    predictions = []
    for idx, sentence in enumerate(sentences, 1):
        prediction = classify_sentence(sentence, prompt_type=prompt_type)
        predictions.append(prediction)
        print(f"Sentence {idx}: \"{sentence}\" => {'Requirement' if prediction else 'Not Requirement'}")
        time.sleep(1)  # To respect rate limits; adjust as necessary

    # Extract ground truth labels
    ground_truth_labels = get_true_label(test_data, column_name="Req/Not Req")[:20]

    # Evaluate the results
    metrics = evaluation(ground_truth_labels, predictions)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Starting classification using Ultimate Prompt prompting.
#
# Processing the following 50 sentences:
#
# 1. System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges.
# 2. Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions.
# 3. As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software.
# 4. System Initialization shall [SRS014] initiate the watchdog timer.
# 5. System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor..
# 6. System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds.
# 7. System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active.
# 8. If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP.
# 9. If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP.
# 10. System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS.
# 11. The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group.
# 12. The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP.
# 13. The application can use this time on the ICP to initialize I/O boards.
# 14. System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance.
# 15. The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP.
# 16. The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal.
# 17. Note that FTSS will not fail the FCR if this signal is not received within this time.
# 18. FTSS will wait until the normal ICP presence test fails.
# 19. The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE.
# 20. System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt.
#
# Classifying...
#
# the response content is: {
#   "reasoning": "The text describes a process or function (System Initialization) and what it does, but it does not specify any mandatory functionality, feature, or constraint. It does not use actionable terms like 'shall', 'must', or 'requires'. It is more of a descriptive statement about the system initialization process, rather than an actionable requirement.",
#   "label": "Non-Requirement"
# }
# Sentence 1: "System Initialization performs those functions necessary to transform the hardware consisting of the FCP processors, network elements, and on-board I/O devices into a real time system executing tasks with fault tolerant message exchanges." => Not Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality that needs to be performed by the System Initialization whenever a power-on reset occurs. It uses the actionable term 'shall' to indicate a requirement. Therefore, it aligns with the definition of a requirement.",
#   "label": "Requirement"
# }
# Sentence 2: "Whenever a power-on reset occurs, System Initialization shall [SRS194] perform the following functions." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the Boot ROM during System Initialization. It uses the actionable term 'shall' to specify that the Boot ROM must be configured to perform certain actions after completing IBIT. This includes calling the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software and the FTSS System Initialization software.",
#   "label": "Requirement"
# }
# Sentence 3: "As part of System Initialization , the Boot ROM shall [SRS234] be configured to, after completing IBIT, call the manufacturer-supplied VxWorks Board Support Package (BSP) initialization software followed by a call to the FTSS System Initialization software." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system, specifically, the system initialization. It uses the actionable term 'shall' to indicate a requirement. The requirement is that the system initialization must initiate the watchdog timer, which is a specific, technical demand.",
#   "label": "Requirement"
# }
# Sentence 4: "System Initialization shall [SRS014] initiate the watchdog timer." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system initialization, using the actionable term 'shall'. It specifies that the system initialization must enable and reset the processor's watchdog timer in a certain way, which is a clear technical demand.",
#   "label": "Requirement"
# }
# Sentence 5: "System Initialization shall [SRS292] enable and reset the processor’s watchdog timer such that, in the absence of a fault, the watchdog timer does not expire and reset the processor.." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system, specifically, the system initialization. It uses the actionable term 'shall' to indicate a requirement. The requirement is specific, stating that the system initialization must synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds.",
#   "label": "Requirement"
# }
# Sentence 6: "System Initialization shall [SRS008] synchronize the FCP virtual group in the presence of a power on skew of 2.5 seconds." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system initialization, using the actionable term 'shall'. It specifies that the FCP virtual group must be configured to use all available synchronized processors, given the condition that at least 3 of the 5 FCRs are active. This is a clear, specific, and actionable requirement.",
#   "label": "Requirement"
# }
# Sentence 7: "System Initialization shall [SRS010] configure the FCP virtual group to use all available synchronized processors, if at least 3 of the 5 FCRs are active." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system in the event of a failure in the FCP processors. It uses the actionable term 'shall' to indicate a requirement. The requirement is specific, stating that the System Initialization in the surviving triplex must attempt to sync with the failed FCP.",
#   "label": "Requirement"
# }
# Sentence 8: "If any of the FCP processors are not synchronized, System Initialization in the surviving triplex shall [SRS177] attempt to sync with the failed FCP." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality and uses the actionable term 'shall'. It specifies a condition (if the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP) and an action that must be taken under that condition (the surviving triplex shall, within 1 second, send a single voted VMEbus reset through the NE to the failed FCP). This is a clear requirement.",
#   "label": "Requirement"
# }
# Sentence 9: "If the failed FCP processor has not synced in 2.5 seconds after the surviving triplex has detected the loss of the FCP, then the surviving triplex shall [SRS178], within 1 second, send a single voted VMEbus reset through the NE to the failed FCP." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system initialization, using the actionable term 'shall'. It specifies that the system initialization must align processor state and congruent aligned memory locations, and further defines what is included in the processor state. Therefore, it aligns with the definition of a requirement.",
#   "label": "Requirement"
# }
# Sentence 10: "System Initialization shall [SRS011] align processor state and congruent aligned memory locations. Processor state includes all registers. It also includes those timers used by FTSS." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality that the FCP must perform, which is to configure ICP simplex virtual groups for each channel in the FCP virtual group. It uses the actionable term 'shall', indicating a requirement.",
#   "label": "Requirement"
# }
# Sentence 11: "The FCP shall [SRS296] configure ICP simplex virtual groups for each channel in the FCP virtual group." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the FCP, which is to wait up to 15 seconds after configuring the ICP virtual groups for communication to start from the ICP. It uses the actionable term 'shall', indicating a requirement.",
#   "label": "Requirement"
# }
# Sentence 12: "The FCP shall [SRS297] wait up to 15 seconds, after configuring the ICP virtual groups, for communication to start from the ICP. " => Requirement
# the response content is: {
#   "reasoning": "The text describes a functionality of the application, specifically, it can use time on the ICP to initialize I/O boards. However, it does not use mandatory language such as 'shall', 'must', or 'requires', and it does not specify that this functionality is a necessary or mandatory feature. Therefore, it is not a requirement.",
#   "label": "Non-Requirement"
# }
# Sentence 13: "The application can use this time on the ICP to initialize I/O boards." => Not Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system initialization, using the actionable term 'shall'. It specifies that the system initialization must call an application initialization function to perform certain tasks, which include creating tasks, creating communication sockets, initializing the vehicle mode, and initializing memory alignment allowance. This aligns with the definition of a requirement.",
#   "label": "Requirement"
# }
# Sentence 14: "System Initialization shall [SRS215] call an application initialization function to allow the application to (at least) create tasks, create communication sockets, initialize the vehicle mode, and initialize memory alignment allowance." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the FCP, which is to send an FCP Ready Sync message to the ICP after application initialization is complete. It uses the actionable term 'shall', indicating a requirement.",
#   "label": "Requirement"
# }
# Sentence 15: "The FCP shall [SRS221], after application initialization is complete, send an FCP Ready Sync message to the ICP." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the FCP, specifying that it must wait up to 2.5 seconds for the ICP Ready signal after sending the FCP Ready Sync. This is an actionable requirement as it uses the term 'shall' to indicate a mandatory action.",
#   "label": "Requirement"
# }
# Sentence 16: "The FCP shall [SRS189] wait up to 2.5 seconds (from the sending of the FCP Ready Sync) for the ICP Ready signal. " => Requirement
# the response content is: {
#   "reasoning": "The text describes a specific behavior of the FTSS in response to a certain condition (not receiving a signal within a certain time). It does not use explicit actionable terms like 'shall', 'must', or 'requires', but it clearly indicates a functional constraint of the system. Therefore, it can be considered as a requirement.",
#   "label": "Requirement"
# }
# Sentence 17: "Note that FTSS will not fail the FCR if this signal is not received within this time." => Requirement
# the response content is: {
#   "reasoning": "The text describes a specific behavior of the FTSS, stating that it will wait until the normal ICP presence test fails. This is a mandatory functionality of the system, and the use of 'will' indicates an actionable requirement.",
#   "label": "Requirement"
# }
# Sentence 18: "FTSS will wait until the normal ICP presence test fails." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the FCP, specifically how it should behave if the NEFU ICP fails to send its ICP Ready signal. It uses the actionable term 'shall' to indicate this requirement. Therefore, it aligns with the definition of a requirement.",
#   "label": "Requirement"
# }
# Sentence 19: "The FCP shall [SRS243], if the NEFU ICP fails to send its ICP Ready signal, mask out that ICP, but continue to use the NE." => Requirement
# the response content is: {
#   "reasoning": "The text describes a mandatory functionality of the system, specifically the system initialization. It uses the actionable term 'shall' to indicate a requirement. The requirement is specific, stating that the system initialization must start the 50 Hz timer and enable the timer interrupt when all other activities are completed.",
#   "label": "Requirement"
# }
# Sentence 20: "System Initialization shall [SRS199], when all other activities are completed, start the 50 Hz timer and enable the timer interrupt. " => Requirement
#
# Evaluation Metrics:
# Accuracy: 0.9
# Precision: 1.0
# Recall: 0.9
# F1 Score: 0.9474

# %%
import json
import openai

# Function to classify the text
def classify_text(text):
    # Define the messages for the chat completion
    messages = [
        {
            "role": "system",
            "content": (
                "You are a highly experienced software engineer with over 25 years of expertise in requirements engineering. "
                "Your role is to carefully distinguish between actionable requirements and supplementary or descriptive information. "
                "You are methodical, objective, and precise in your analysis."
            )
        },
        {
            "role": "user",
            "content": 
            """
            ### Task: Classify the following text as "requirement" or "non-requirement."

            ### Definitions:
            - *Requirement:* A statement that specifies a mandatory functionality, feature, constraint, or operational need. It typically uses actionable terms like "shall," "must," "requires," or clearly indicates a technical or functional demand.
            - *Non-Requirement:* A statement that is descriptive, procedural, informational, or otherwise lacks specificity about a mandatory functionality or constraint. These may reference requirements without being actionable themselves.

            ### Instructions:
            1. Read the text carefully.
            2. Compare it to the definitions provided above.
            3. Follow this decision-making process:
                - *Step 1:* Does the text describe a mandatory functionality, feature, or constraint?
                - *Step 2:* Does it include actionable terms such as "shall," "must," "requires," or similar?
                - *Step 3:* If descriptive, procedural, or lacking specificity, classify as "non-requirement."
            4. Be neutral and avoid assuming the text belongs to a specific class. Use examples to guide your decision.
            5. Output your classification in the following JSON format:

            json
            {{
                "reasoning": "{step-by-step reasoning here. Highlight whether the text aligns with actionable requirements or descriptive content.}",
                "label": "{Requirement/Non-Requirement}"
            }}

            ### Analyze and Classify:
            Text: "|text|"
            
            """
        }
    ]

    print(messages)
    
    messages[1]["content"] = messages[1]["content"].replace("|text|", text)
    
    print("modift", messages)
    
    # Call OpenAI API to get the classification result
    response = openai.ChatCompletion.create(
        model="gpt-4",  # Use a chat-based model
        messages=messages,
        max_tokens=500,
        temperature=0
    )
    
    # print(response)

    # Parse the response to extract the label
    try:
        # Get the content from the response
        content = response['choices'][0]['message']['content']
        # Parse the JSON content from the assistant's response
        result_data = json.loads(content)
        print(result_data)
        
        # Extract and return the label
        label = result_data['label']
        return label
    except (json.JSONDecodeError, KeyError) as e:
        return f"Error parsing response: {e}"

# Test the function with a sample text
sample_text = "The system shall log all user activities for auditing purposes."
result_label = classify_text(sample_text)

# Print only the classification label (Requirement/Non-Requirement)
print(result_label)
# Out:
# [{'role': 'system', 'content': 'You are a highly experienced software engineer with over 25 years of expertise in requirements engineering. Your role is to carefully distinguish between actionable requirements and supplementary or descriptive information. You are methodical, objective, and precise in your analysis.'}, {'role': 'user', 'content': '\n            ### Task: Classify the following text as "requirement" or "non-requirement."\n\n            ### Definitions:\n            - *Requirement:* A statement that specifies a mandatory functionality, feature, constraint, or operational need. It typically uses actionable terms like "shall," "must," "requires," or clearly indicates a technical or functional demand.\n            - *Non-Requirement:* A statement that is descriptive, procedural, informational, or otherwise lacks specificity about a mandatory functionality or constraint. These may reference requirements without being actionable themselves.\n\n            ### Instructions:\n            1. Read the text carefully.\n            2. Compare it to the definitions provided above.\n            3. Follow this decision-making process:\n                - *Step 1:* Does the text describe a mandatory functionality, feature, or constraint?\n                - *Step 2:* Does it include actionable terms such as "shall," "must," "requires," or similar?\n                - *Step 3:* If descriptive, procedural, or lacking specificity, classify as "non-requirement."\n            4. Be neutral and avoid assuming the text belongs to a specific class. Use examples to guide your decision.\n            5. Output your classification in the following JSON format:\n\n            json\n            {{\n                "reasoning": "{step-by-step reasoning here. Highlight whether the text aligns with actionable requirements or descriptive content.}",\n                "label": "{Requirement/Non-Requirement}"\n            }}\n\n            ### Analyze and Classify:\n            Text: "|text|"\n            \n            '}]
# modift [{'role': 'system', 'content': 'You are a highly experienced software engineer with over 25 years of expertise in requirements engineering. Your role is to carefully distinguish between actionable requirements and supplementary or descriptive information. You are methodical, objective, and precise in your analysis.'}, {'role': 'user', 'content': '\n            ### Task: Classify the following text as "requirement" or "non-requirement."\n\n            ### Definitions:\n            - *Requirement:* A statement that specifies a mandatory functionality, feature, constraint, or operational need. It typically uses actionable terms like "shall," "must," "requires," or clearly indicates a technical or functional demand.\n            - *Non-Requirement:* A statement that is descriptive, procedural, informational, or otherwise lacks specificity about a mandatory functionality or constraint. These may reference requirements without being actionable themselves.\n\n            ### Instructions:\n            1. Read the text carefully.\n            2. Compare it to the definitions provided above.\n            3. Follow this decision-making process:\n                - *Step 1:* Does the text describe a mandatory functionality, feature, or constraint?\n                - *Step 2:* Does it include actionable terms such as "shall," "must," "requires," or similar?\n                - *Step 3:* If descriptive, procedural, or lacking specificity, classify as "non-requirement."\n            4. Be neutral and avoid assuming the text belongs to a specific class. Use examples to guide your decision.\n            5. Output your classification in the following JSON format:\n\n            json\n            {{\n                "reasoning": "{step-by-step reasoning here. Highlight whether the text aligns with actionable requirements or descriptive content.}",\n                "label": "{Requirement/Non-Requirement}"\n            }}\n\n            ### Analyze and Classify:\n            Text: "The system shall log all user activities for auditing purposes."\n            \n            '}]
# {'reasoning': "The text describes a mandatory functionality of the system, which is to log all user activities. It uses the actionable term 'shall', indicating a requirement.", 'label': 'Requirement'}
# Requirement
